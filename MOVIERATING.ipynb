# %%
import pandas as pd
import os

# %%
movie=pd.read_csv("/Users/pankaj/Downloads/P4-Movie-Ratings.csv")

# %%
os.getcwd()
# Out:
# '/Users/pankaj'

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# 2                    52                  20             2009
# 3                    84                  18             2010
# 4                    70                  20             2009
# ..                  ...                 ...              ...
# 554                  36                  50             2011
# 555                  52                  18             2009
# 556                  73                  65             2007
# 557                  87                  24             2009
# 558                  42                  80             2011
#
# [559 rows x 6 columns]

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns=['Film', 'Genre', 'criticRatings', 'audienceRatings',
       'Budgetmillion', 'Yearrelease']

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'criticRatings', 'audienceRatings', 'Budgetmillion',
#        'Yearrelease'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(movie.Budgetmillion)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 10 Patch objects>)

# %%
movie.Genre=="action"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 554    True
# 555    True
# 556    True
# 557    True
# 558    True
# Name: Genre, Length: 559, dtype: bool

# %%
movie.head()
# Out:
#                     Film      Genre  criticRatings  audienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Yearrelease
# 0              8         2009
# 1            105         2008
# 2             20         2009
# 3             18         2010
# 4             20         2009

# %%
movie[movie.Genre=="Action"]
# Out:
#                           Film   Genre  criticRatings  audienceRatings  \
# 2                   12 Rounds   Action             30               52
# 5                         2012  Action             39               63
# 15                   Abduction  Action              4               46
# 29                   Appaloosa  Action             77               55
# 30                    Armored   Action             40               34
# ..                         ...     ...            ...              ...
# 531                  Watchmen   Action             64               68
# 542                  Whiteout   Action              7               28
# 546  X-Men Origins: Wolverine   Action             37               72
# 547         X-Men: First Class  Action             87               88
# 557                Zombieland   Action             90               87
#
#      Budgetmillion  Yearrelease
# 2               20         2009
# 5              200         2009
# 15              35         2011
# 29              20         2008
# 30              20         2009
# ..             ...          ...
# 531            130         2009
# 542             35         2009
# 546            150         2009
# 547            160         2011
# 557             24         2009
#
# [154 rows x 6 columns]

# %%
movie[movie.Genre=="Action"].Budgetmillion
# Out:
# 2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: Budgetmillion, Length: 154, dtype: int64

# %%
plt.hist(movie[movie.Genre=="Action"].Budgetmillion)
plt.hist(movie[movie.Genre=="Comedy"].Budgetmillion)
plt.show()

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null object
# Genre              559 non-null object
# criticRatings      559 non-null int64
# audienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Yearrelease        559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.Film=movie.Film.astype('category')
movie.Genre=movie.Genre.astype('category')
movie.Yearrelease=movie.Yearrelease.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# criticRatings      559 non-null int64
# audienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Yearrelease        559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movie.Yearrelease
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Yearrelease, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movie.head()
# Out:
#                     Film      Genre  criticRatings  audienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion Yearrelease
# 0              8        2009
# 1            105        2008
# 2             20        2009
# 3             18        2010
# 4             20        2009

# %%
movie.tail()
# Out:
#                 Film     Genre  criticRatings  audienceRatings  Budgetmillion  \
# 554    Your Highness    Comedy             26               36             50
# 555  Youth in Revolt    Comedy             68               52             18
# 556           Zodiac  Thriller             89               73             65
# 557      Zombieland     Action             90               87             24
# 558        Zookeeper    Comedy             14               42             80
#
#     Yearrelease
# 554        2011
# 555        2009
# 556        2007
# 557        2009
# 558        2011

# %%
movie.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# criticRatings      559 non-null int64
# audienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Yearrelease        559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
a=movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
for i in movie.Genre.cat.categories:
    plt.hist(movie[movie.Genre==i].Budgetmillion,stacked="True",bins=10,label=i)
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
for i in movie.Genre.cat.categories:
    sns.distplot(movie[movie.Genre==i].Budgetmillion,bins=10,label=i)
